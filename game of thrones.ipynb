# %% [markdown]
# ### Import the necessary libraries

# %%
import pandas as pd # analysing the data
import seaborn as sns# visulisation
import matplotlib.pyplot as plt  # visualisation

# %% [markdown]
# ### import the file

# %%
df=pd.read_csv('battles.csv')
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
df.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
for i in df.columns:
    print(i)
    print(df[i].value_counts())
    print('-----------------------*********---------------------------')
# Out:
# name
# Retaking of Harrenhal                                   1
# Siege of Dragonstone                                    1
# Fall of Moat Cailin                                     1
# Battle of the Green Fork                                1
# Battle of Duskendale                                    1
# Battle of the Camps                                     1
# Siege of Riverrun                                       1
# Battle of the Whispering Wood                           1
# Battle of Deepwood Motte                                1
# Battle of the Burning Septry                            1
# Battle of the Ruby Ford                                 1
# Sack of Torrhen's Square                                1
# Battle of the Stony Shore                               1
# Retaking of Deepwood Motte                              1
# Invasion of Ryamsport, Vinetown, and Starfish Harbor    1
# Battle of the Blackwater                                1
# ...

# %% [markdown]
# # what were the locations of the battles

# %%
df['location'].value_counts()
# Out:
# Winterfell                              3
# Riverrun                                3
# Storm's End                             2
# Torrhen's Square                        2
# Harrenhal                               2
# Darry                                   2
# Moat Cailin                             2
# Deepwood Motte                          2
# Duskendale                              1
# Oxcross                                 1
# Raventree                               1
# Saltpans                                1
# Red Fork                                1
# Crag                                    1
# King's Landing                          1
# Seagard                                 1
# Ryamsport, Vinetown, Starfish Harbor    1
# Green Fork                              1
# Dragonstone                             1
# Stony Shore                             1
# Castle Black                            1
# Shield Islands                          1
# ...

# %%
df["location"].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # In which region does most battle have occures

# %%
df['region'].value_counts()
# Out:
# The Riverlands     17
# The North          10
# The Stormlands      3
# The Westerlands     3
# The Reach           2
# The Crownlands      2
# Beyond the Wall     1
# Name: region, dtype: int64

# %%
df["region"].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
a=df[['name','year']]

# %%
a
# Out:
#                                                  name  year
# 0                          Battle of the Golden Tooth   298
# 1                         Battle at the Mummer's Ford   298
# 2                                  Battle of Riverrun   298
# 3                            Battle of the Green Fork   298
# 4                       Battle of the Whispering Wood   298
# 5                                 Battle of the Camps   298
# 6                                       Sack of Darry   298
# 7                               Battle of Moat Cailin   299
# 8                            Battle of Deepwood Motte   299
# 9                           Battle of the Stony Shore   299
# 10                         Battle of Torrhen's Square   299
# 11                               Battle of Winterfell   299
# 12                           Sack of Torrhen's Square   299
# 13                                 Sack of Winterfell   299
# 14                                  Battle of Oxcross   299
# ...

# %% [markdown]
# # how many battles have occured in 298

# %%
a[a.year==298]
# Out:
#                             name  year
# 0     Battle of the Golden Tooth   298
# 1    Battle at the Mummer's Ford   298
# 2             Battle of Riverrun   298
# 3       Battle of the Green Fork   298
# 4  Battle of the Whispering Wood   298
# 5            Battle of the Camps   298
# 6                  Sack of Darry   298

# %% [markdown]
# # how many battles have occured in 299

# %%
b=a[a.year==299]
b
# Out:
#                             name  year
# 7          Battle of Moat Cailin   299
# 8       Battle of Deepwood Motte   299
# 9      Battle of the Stony Shore   299
# 10    Battle of Torrhen's Square   299
# 11          Battle of Winterfell   299
# 12      Sack of Torrhen's Square   299
# 13            Sack of Winterfell   299
# 14             Battle of Oxcross   299
# 15          Siege of Storm's End   299
# 16           Battle of the Fords   299
# 17             Sack of Harrenhal   299
# 18            Battle of the Crag   299
# 19      Battle of the Blackwater   299
# 20                Siege of Darry   299
# 21          Battle of Duskendale   299
# 22  Battle of the Burning Septry   299
# 23       Battle of the Ruby Ford   299
# 24         Retaking of Harrenhal   299
# 25               The Red Wedding   299
# 26              Siege of Seagard   299

# %% [markdown]
# 20 battles have occured in 299

# %%
print(len(b))
# Out:
# 20

# %% [markdown]
# # how many battles have occured in 300

# %%
c=a[a.year==300]

# %%
c
# Out:
#                                                  name  year
# 27                             Battle of Castle Black   300
# 28                                Fall of Moat Cailin   300
# 29                                   Sack of Saltpans   300
# 30                         Retaking of Deepwood Motte   300
# 31                       Battle of the Shield Islands   300
# 32  Invasion of Ryamsport, Vinetown, and Starfish ...   300
# 33                        Second Seige of Storm's End   300
# 34                               Siege of Dragonstone   300
# 35                                  Siege of Riverrun   300
# 36                                 Siege of Raventree   300
# 37                                Siege of Winterfell   300

# %% [markdown]
# 11 battles have occured in 300 ac

# %%
print(len(c))
# Out:
# 11

# %% [markdown]
# # In which battle and which is the attacker king

# %%
d=df[['name','attacker_king','year']]

# %%
d
# Out:
#                                                  name  \
# 0                          Battle of the Golden Tooth
# 1                         Battle at the Mummer's Ford
# 2                                  Battle of Riverrun
# 3                            Battle of the Green Fork
# 4                       Battle of the Whispering Wood
# 5                                 Battle of the Camps
# 6                                       Sack of Darry
# 7                               Battle of Moat Cailin
# 8                            Battle of Deepwood Motte
# 9                           Battle of the Stony Shore
# 10                         Battle of Torrhen's Square
# 11                               Battle of Winterfell
# 12                           Sack of Torrhen's Square
# 13                                 Sack of Winterfell
# 14                                  Battle of Oxcross
# 15                               Siege of Storm's End
# ...

# %% [markdown]
# # which battle have won by major death  0 and which battle has won by major_death 1

# %%
e=df[['attacker_king','attacker_outcome','major_death','name']]
e
# Out:
#                attacker_king attacker_outcome  major_death  \
# 0   Joffrey/Tommen Baratheon              win          1.0
# 1   Joffrey/Tommen Baratheon              win          1.0
# 2   Joffrey/Tommen Baratheon              win          0.0
# 3                 Robb Stark             loss          1.0
# 4                 Robb Stark              win          1.0
# 5                 Robb Stark              win          0.0
# 6   Joffrey/Tommen Baratheon              win          0.0
# 7        Balon/Euron Greyjoy              win          0.0
# 8        Balon/Euron Greyjoy              win          0.0
# 9        Balon/Euron Greyjoy              win          0.0
# 10                Robb Stark              win          0.0
# 11       Balon/Euron Greyjoy              win          0.0
# 12       Balon/Euron Greyjoy              win          0.0
# 13  Joffrey/Tommen Baratheon              win          1.0
# 14                Robb Stark              win          1.0
# ...

# %%
e=e.sort_values(by=['major_death'],ascending=False)

# %%
e
# Out:
#                attacker_king attacker_outcome  major_death  \
# 0   Joffrey/Tommen Baratheon              win          1.0
# 27         Stannis Baratheon             loss          1.0
# 21                Robb Stark             loss          1.0
# 25  Joffrey/Tommen Baratheon              win          1.0
# 19         Stannis Baratheon             loss          1.0
# 1   Joffrey/Tommen Baratheon              win          1.0
# 17                Robb Stark              win          1.0
# 15         Stannis Baratheon              win          1.0
# 14                Robb Stark              win          1.0
# 13  Joffrey/Tommen Baratheon              win          1.0
# 24  Joffrey/Tommen Baratheon              win          1.0
# 4                 Robb Stark              win          1.0
# 3                 Robb Stark             loss          1.0
# 23  Joffrey/Tommen Baratheon              win          0.0
# 29                       NaN              win          0.0
# ...

# %% [markdown]
# # my top wins in this battle

# %%
e[(e.attacker_outcome=='win')&(e.major_death==0)]
# Out:
#                attacker_king attacker_outcome  major_death  \
# 23  Joffrey/Tommen Baratheon              win          0.0
# 29                       NaN              win          0.0
# 30         Stannis Baratheon              win          0.0
# 31       Balon/Euron Greyjoy              win          0.0
# 32       Balon/Euron Greyjoy              win          0.0
# 26                Robb Stark              win          0.0
# 33  Joffrey/Tommen Baratheon              win          0.0
# 34  Joffrey/Tommen Baratheon              win          0.0
# 35  Joffrey/Tommen Baratheon              win          0.0
# 28  Joffrey/Tommen Baratheon              win          0.0
# 18                Robb Stark              win          0.0
# 22                       NaN              win          0.0
# 20                Robb Stark              win          0.0
# 12       Balon/Euron Greyjoy              win          0.0
# 11       Balon/Euron Greyjoy              win          0.0
# ...

# %% [markdown]
# # how many battles have won by major death 1 by attackers

# %%
e[(e.attacker_outcome=='win')&(e.major_death==1)]
# Out:
#                attacker_king attacker_outcome  major_death
# 0   Joffrey/Tommen Baratheon              win          1.0
# 25  Joffrey/Tommen Baratheon              win          1.0
# 1   Joffrey/Tommen Baratheon              win          1.0
# 17                Robb Stark              win          1.0
# 15         Stannis Baratheon              win          1.0
# 14                Robb Stark              win          1.0
# 13  Joffrey/Tommen Baratheon              win          1.0
# 24  Joffrey/Tommen Baratheon              win          1.0
# 4                 Robb Stark              win          1.0

# %% [markdown]
# # which king have loss the battle

# %%
e[(e.attacker_outcome=='loss')]
# Out:
#                attacker_king attacker_outcome  major_death
# 27         Stannis Baratheon             loss          1.0
# 21                Robb Stark             loss          1.0
# 19         Stannis Baratheon             loss          1.0
# 3                 Robb Stark             loss          1.0
# 16  Joffrey/Tommen Baratheon             loss          0.0

# %% [markdown]
# # kings who won the match or not

# %%
sns.countplot(x='attacker_king',hue='attacker_outcome',data=e)
# Out:
# <AxesSubplot:xlabel='attacker_king', ylabel='count'>

# %%
f=df[['attacker_king','battle_type','attacker_size','defender_size','defender_king']]
f
# Out:
#                attacker_king     battle_type  attacker_size  defender_size  \
# 0   Joffrey/Tommen Baratheon  pitched battle        15000.0         4000.0
# 1   Joffrey/Tommen Baratheon          ambush            NaN          120.0
# 2   Joffrey/Tommen Baratheon  pitched battle        15000.0        10000.0
# 3                 Robb Stark  pitched battle        18000.0        20000.0
# 4                 Robb Stark          ambush         1875.0         6000.0
# 5                 Robb Stark          ambush         6000.0        12625.0
# 6   Joffrey/Tommen Baratheon  pitched battle            NaN            NaN
# 7        Balon/Euron Greyjoy  pitched battle            NaN            NaN
# 8        Balon/Euron Greyjoy           siege         1000.0            NaN
# 9        Balon/Euron Greyjoy          ambush          264.0            NaN
# 10                Robb Stark  pitched battle          244.0          900.0
# ...

# %% [markdown]
# # top attcker king

# %%
df['attacker_king'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # top defender king

# %%
df['defender_king'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # attackers battle type

# %%
sns.countplot(x='attacker_king',hue='battle_type',data=f)
# Out:
# <AxesSubplot:xlabel='attacker_king', ylabel='count'>

# %% [markdown]
# # size of attackers

# %%
sns.barplot(x='attacker_size',y='attacker_king',data=f)
# Out:
# <AxesSubplot:xlabel='attacker_size', ylabel='attacker_king'>

# %% [markdown]
# # defedners size

# %%
sns.barplot(x='defender_size',y='defender_king',data=f)
# Out:
# <AxesSubplot:xlabel='defender_size', ylabel='defender_king'>

# %% [markdown]
# # No of battles per year

# %%
battle=df[['battle_number','year']]

# %%
battle
# Out:
#     battle_number  year
# 0               1   298
# 1               2   298
# 2               3   298
# 3               4   298
# 4               5   298
# 5               6   298
# 6               7   298
# 7               8   299
# 8               9   299
# 9              10   299
# 10             11   299
# 11             12   299
# 12             13   299
# 13             14   299
# 14             15   299
# 15             16   299
# 16             17   299
# 17             18   299
# 18             19   299
# 19             20   299
# 20             21   299
# 21             22   299
# 22             23   299
# 23             24   299
# 24             25   299
# 25             26   299
# 26             27   299
# 27             28   300
# 28             29   300
# 29             30   300
# 30             31   300
# 31             32   300
# 32             33   300
# 33             34   300
# 34             35   300
# 35             36   300
# 36             37   300
# ...

# %% [markdown]
# # battles no year wise

# %%
sns.barplot(x='year',y='battle_number',data=battle)
# Out:
# <AxesSubplot:xlabel='year', ylabel='battle_number'>

# %%
g
# Out:
#                                    attacker_commander  \
# 0                                     Jaime Lannister
# 1                                      Gregor Clegane
# 2                        Jaime Lannister, Andros Brax
# 3   Roose Bolton, Wylis Manderly, Medger Cerwyn, H...
# 4                           Robb Stark, Brynden Tully
# 5          Robb Stark, Tytos Blackwood, Brynden Tully
# 6                                      Gregor Clegane
# 7                                   Victarion Greyjoy
# 8                                        Asha Greyjoy
# 9                                       Theon Greyjoy
# 10                         Rodrik Cassel, Cley Cerwyn
# 11                                      Theon Greyjoy
# 12                                    Dagmer Cleftjaw
# 13                        Ramsay Snow, Theon Greyjoy
# 14                          Robb Stark, Brynden Tully
# 15                  Stannis Baratheon, Davos Seaworth
# ...

# %% [markdown]
# # top attacker_commander

# %%
df["attacker_commander"].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df['defender_king'].mode()
# Out:
# 0    Robb Stark
# dtype: object

# %%
df['attacker_king'].mode()
# Out:
# 0    Joffrey/Tommen Baratheon
# dtype: object

# %%
df['attacker_commander'].mode()
# Out:
# 0    Gregor Clegane
# dtype: object

# %%
df['defender_commander'].mode()
# Out:
# 0                                           Amory Lorch
# 1                                          Asha Greyjoy
# 2                                      Beric Dondarrion
# 3                                            Bran Stark
# 4                                         Brynden Tully
# 5                                  Clement Piper, Vance
# 6                                       Dagmer Cleftjaw
# 7            Edmure Tully, Jason Mallister, Karyl Vance
# 8                         Edmure Tully, Tytos Blackwood
# 9                                       Gilbert Farring
# 10                                      Jaime Lannister
# 11                                      Jason Mallister
# 12                     Lord Andros Brax, Forley Prester
# 13                                          Lyman Darry
# 14                        Randyll Tarly, Gregor Clegane
# 15    Renly Baratheon, Cortnay Penrose, Loras Tyrell...
# 16                                           Robb Stark
# ...

# %%
df['defender_size'].max()
# Out:
# 20000.0

# %%
df['battle_type'].mode()
# Out:
# 0    pitched battle
# dtype: object

# %%
df['region'].mode()
# Out:
# 0    The Riverlands
# dtype: object

# %%
df['location'].mode()
# Out:
# 0      Riverrun
# 1    Winterfell
# dtype: object
